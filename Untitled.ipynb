# %% [markdown]
# # Misalignment of proprioceptive and visual estimates of limb position
# ## Gregg Eschelmuller
# ### 482 Presentation

# %% [markdown]
# # Bias in a targeting task
# ![image.png](attachment:174b5e99-7c5a-4867-babc-e39323781381.png)
#
# - When participants are asked to move their unseen hand to a target, we commonly see a bias in end point. More specifically, in joint extension
